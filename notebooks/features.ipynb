# %% [markdown]
# # Feature Engineering
#
# - 1. [Introduction](#1.-Introduction)
# - 2. [Imports](#2.-Imports)
# - 3. [Loading the data](#3.-Loading-the-data)
# - 4. [Partitioning Our Dataset](#4.-Partitioning-Our-Dataset)
# - 5. [Defining Our Preprocessing Pipeline](#5.-Defining-Our-Preprocessing-Pipeline)
#     - 5.1 Pipeline Definition
# - 6. [Exporting Preprocessed Data](#6.-Exporting-Preprocessed-Data)

# %% [markdown]
# ## 1. Introduction
# This notebook is dedicated to developing features for our later models to ingest. It includes imputation, scaling, one-hot encoding, transformation, outlier handling, and data splitting. Methods for re-sampling the dataset to handle class imbalances will not occur in this phase, but rather the model evaluation phase.

# %% [markdown]
# ## 2. Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import os
import seaborn as sns

from category_encoders import OrdinalEncoder

from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.pipeline import Pipeline

from sklearndf.transformation import SimpleImputerDF, StandardScalerDF, FunctionTransformerDF, VarianceThresholdDF, OneHotEncoderDF

from src.data import load_dataset as ld
from src.features.icd9 import icd9_to_classification, is_diabetes_mellitus, icd9_to_category
from src.features.age import age_to_index

from src.features.transformer import PandasFeatureUnion, RowFilter, ColumnSelector, ColumnFilter, \
DiagnosisMapper, EncodeNaNCategoricalImputer, MostFrequentCategoricalImputer, CategoryCollapseThreshold, \
CategoricalHomogeneityThreshold, FeatureCombiner

sns.set()
pd.options.display.max_columns = 100

RANDOM_SEED = 0

# %% [markdown]
# ## 3. Loading the data

# %%
df = ld.load_interim_pickle('00_diabetes.pkl')
df.head()
# Out:
#                                      race  gender       age admission_type_id  \
# encounter_id patient_nbr
# 12522        48330783           Caucasian  Female   [80-90)                 2
# 15738        63555939           Caucasian  Female  [90-100)                 3
# 16680        42519267           Caucasian    Male   [40-50)                 1
# 28236        89869032     AfricanAmerican  Female   [40-50)                 1
# 35754        82637451           Caucasian    Male   [50-60)                 2
#
#                          discharge_disposition_id admission_source_id  \
# encounter_id patient_nbr
# 12522        48330783                           1                   4
# 15738        63555939                           3                   4
# 16680        42519267                           1                   7
# 28236        89869032                           1                   7
# 35754        82637451                           1                   2
#
#                           days_in_hospital payer_code medical_specialty  \
# encounter_id patient_nbr
# 12522        48330783                   13         NA     Not Available
# 15738        63555939                   12         NA  InternalMedicine
# 16680        42519267                    1         NA     Not Available
# 28236        89869032                    9         NA     Not Available
# 35754        82637451                    3         NA     Not Available
#
#                           num_lab_procedures  num_procedures  num_medications  \
# encounter_id patient_nbr
# 12522        48330783                     68               2               28
# 15738        63555939                     33               3               18
# 16680        42519267                     51               0                8
# 28236        89869032                     47               2               17
# 35754        82637451                     31               6               16
#
#                           number_outpatient  number_emergency  \
# encounter_id patient_nbr
# 12522        48330783                     0                 0
# 15738        63555939                     0                 0
# 16680        42519267                     0                 0
# 28236        89869032                     0                 0
# 35754        82637451                     0                 0
#
#                           number_inpatient diag_1 diag_2 diag_3  \
# encounter_id patient_nbr
# 12522        48330783                    0    398    427     38
# 15738        63555939                    0    434    198    486
# 16680        42519267                    0    197    157    250
# 28236        89869032                    0  250.7    403    996
# 35754        82637451                    0    414    411    250
#
#                           number_diagnoses  max_glu_serum      A1Cresult  \
# encounter_id patient_nbr
# 12522        48330783                    8  Not Available  Not Available
# 15738        63555939                    8  Not Available  Not Available
# 16680        42519267                    5  Not Available  Not Available
# 28236        89869032                    9  Not Available  Not Available
# 35754        82637451                    9  Not Available  Not Available
#
#                          metformin repaglinide nateglinide chlorpropamide  \
# encounter_id patient_nbr
# 12522        48330783           No          No          No             No
# 15738        63555939           No          No          No             No
# 16680        42519267           No          No          No             No
# 28236        89869032           No          No          No             No
# 35754        82637451           No          No          No             No
#
#                          glimepiride acetohexamide glipizide glyburide  \
# encounter_id patient_nbr
# 12522        48330783             No            No    Steady        No
# 15738        63555939             No            No        No        No
# 16680        42519267             No            No    Steady        No
# 28236        89869032             No            No        No        No
# 35754        82637451             No            No        No        No
#
#                          tolbutamide pioglitazone rosiglitazone acarbose  \
# encounter_id patient_nbr
# 12522        48330783             No           No            No       No
# 15738        63555939             No           No        Steady       No
# 16680        42519267             No           No            No       No
# 28236        89869032             No           No            No       No
# 35754        82637451             No           No            No       No
#
#                          miglitol troglitazone tolazamide examide citoglipton  \
# encounter_id patient_nbr
# 12522        48330783          No           No         No      No          No
# 15738        63555939          No           No         No      No          No
# 16680        42519267          No           No         No      No          No
# 28236        89869032          No           No         No      No          No
# 35754        82637451          No           No         No      No          No
#
#                          insulin glyburide-metformin glipizide-metformin  \
# encounter_id patient_nbr
# 12522        48330783     Steady                  No                  No
# 15738        63555939     Steady                  No                  No
# 16680        42519267     Steady                  No                  No
# 28236        89869032     Steady                  No                  No
# 35754        82637451     Steady                  No                  No
#
#                          glimepiride-pioglitazone metformin-rosiglitazone  \
# encounter_id patient_nbr
# 12522        48330783                          No                      No
# 15738        63555939                          No                      No
# 16680        42519267                          No                      No
# 28236        89869032                          No                      No
# 35754        82637451                          No                      No
#
#                          metformin-pioglitazone change diabetesMed  \
# encounter_id patient_nbr
# 12522        48330783                        No     Ch         Yes
# 15738        63555939                        No     Ch         Yes
# 16680        42519267                        No     Ch         Yes
# 28236        89869032                        No     No         Yes
# 35754        82637451                        No     No         Yes
#
#                          is_readmitted_early
# encounter_id patient_nbr
# 12522        48330783                      0
# 15738        63555939                      0
# 16680        42519267                      0
# 28236        89869032                      0
# 35754        82637451                      0

# %% [markdown]
# ## 4. Partitioning Our Dataset
# We must first partition our training and test sets. The two sets should be stratified to ensure that we have an approximately equal distribution of positive and negative observations. We will be fitting our preprocessor on our training set and preprocessing both the training and test set.

# %%
X = df.drop(columns=['is_readmitted_early'])
y = df.is_readmitted_early

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=RANDOM_SEED, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((57214, 46), (14304, 46), (57214,), (14304,))

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.912015
# 1    0.087985
# Name: is_readmitted_early, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.911983
# 1    0.088017
# Name: is_readmitted_early, dtype: float64

# %% [markdown]
# ## 5. Defining Our Preprocessing Pipeline
# We will be building two preprocessors: one that includes one-hot encoding and one that doesn't. Tree-based algorithms don't require that categorical variables be encoded numerically, so we will use the former to speed up training for those kinds of models.

# %%
# Columns that we found were homogeneous or had a high NaN values in EDA
columns_to_drop = [
    'payer_code',
    'examide',
    'citoglipton',
    'glimepiride-pioglitazone'
]

categorical_features = X.select_dtypes(exclude=[np.number]).drop(columns=columns_to_drop)
nominal_features = categorical_features.drop(columns=['age']).columns.tolist()
ordinal_features = ['age']
numerical_features = X.select_dtypes(include=[np.number]).columns.tolist()
diagnosis_features = ['diag_1', 'diag_2', 'diag_3']
target_feature = ['is_readmitted_early']


# Features where we want null/nan values to be encoded as their own category
encode_nan_as_category_features = ['diag_1', 'diag_2', 'diag_3', 'gender', 'max_glu_serum', 'medical_specialty', 'A1Cresult']

# We created custom categories for the following columns to indicate unavailability
encode_nan_as_category_special_cases = {
    'admission_type_id': 5,
    'discharge_disposition_id': 25,
    'admission_source_id': 15,
    'race': 'Unknown/Invalid'
}

# For the remaining nominal features, we will just use the most frequent category in our training set
most_frequent_category_features = list(set(nominal_features) - set(encode_nan_as_category_features))

# When merging small categories into one category, we have label specifications for the following columns
merge_categories_special_cases = {
    'discharge_disposition_id': 30,
    'admission_type_id': 9,
    'admission_source_id': 27  
}

row_filters = {
    # Expired or Hospice-related discharges are not likely to be readmitted. Remove neonatal observations
    'discharge_disposition_id': lambda s: ~s.isin([11, 13, 14, 19, 20, 21, 10]),
    # We remove observations related to birth or infancy
    'admission_source_id': lambda s: ~s.isin([11, 12, 13, 14])
}
 
def compute_entropy(d1, d2, d3):
    diagnoses = [d1, d2, d3]
    num_diagnoses = len(diagnoses)
    prob_d1 = diagnoses.count(d1) / num_diagnoses
    prob_d2 = diagnoses.count(d2) / num_diagnoses
    prob_d3 = diagnoses.count(d3) / num_diagnoses
    return -(prob_d1 * np.log(prob_d1) + prob_d2 * np.log(prob_d2) + prob_d3 * np.log(prob_d3)) 

def diagnosis_diversity(r):
    d1 = icd9_to_category(r.diag_1)
    d2 = icd9_to_category(r.diag_2)
    d3 = icd9_to_category(r.diag_3)
    return compute_entropy(d1, d2, d3)

combined_numerical_features = [
    (('number_inpatient', 'number_outpatient', 'number_emergency'), np.sum, 'service_utilization')
]

combined_nominal_features = [
    (('diag_1', 'diag_2', 'diag_3'), diagnosis_diversity, 'diagnosis_diversity')
]

# %% [markdown]
# ### 5.1 Pipeline Definition
# 1. **ColumnFilter**: filter out unwanted columns based on our prior exploratory data analysis. These columns are defined in the `columns_to_drop` variable
# 2. **RowFilter**: drop observations that have invalid values. These are defined in `row_filters`.
# 3. **Numerical Features Sub-pipeline:**
#     - **ColumnFilter**: only select numerical features (e.g. `numerical_features`)
#     - **SimpleImputer**: Impute missing values with the median of each column.
#     - **Log1pTransformer**: Log-transform all columns for additivity and to promote normality.
#     - **StandardScaler**: Centering the data (mean=0, std=1).
#     - **FeatureCombiner**: Create compound features composed of various existing features. These are defined in `combined_numerical_features`.
#     - **VarianceThreshold**: Remove homogeneous features that have a variance lower than a particular threshold. I chose 0.1 for this project.
# 4. **Ordinal Features Sub-pipeline:**
#     - **ColumnFilter**: only select ordinal features (e.g. `ordinal_features`)
#     - **SimpleImputer**: Impute missing values with the most frequently occurring feature value.
#     - **OrdinalEncoder**: Map each category to an index.
#
# 5. **Nominal Features Sub-pipeline:**
#     - **ColumnFilter**: only select nominal features (e.g. `nominal_features`)
#     - **EncodeNaNCategoricalImputer**: For some features (`encode_nan_as_category_features`), we want to encode NaN as its own category because it contains some useful information.
#     - **MostFrequentImputer**: Impute missing values with the most frequently occurring feature value. This custom imputer only does this for a subset of features (`most_frequent_category_features`).
#     - **FeatureCombiner**:  Create compound features composed of various existing features. These are defined in `combined_nominal_features`. We mainly use this to create `diagnosis_diversity`, which measures the heterogeneity in the primary, secondary, and tertiary diagnosis reported.
#     - **DiagnosisMapper**: Converts ICD9 codes into two tiers of classifications (t1, t2), differing by specificity. t2 is more general than t1.
#     - **HomogeneityThreshold**: Remove features if they're too homogeneous, based on Shannon Entropy. I set this threshold to be below 0.05.
#     - **CategoryCollapseThreshold**: Collapse feature values that occur less than X% of the time into a single value. I set this threshold to be below 5%.
#     - **OneHotEncoder**: One-hot encode all features (optional)

# %%
def create_pipeline():
    nominal_transformers = [
        ('column_selector', ColumnSelector(nominal_features)),
        ('encode_nan_as_category_imputer', EncodeNaNCategoricalImputer(encode_nan_as_category_features, special_cases=encode_nan_as_category_special_cases)),
        ('most_frequent_imputer', MostFrequentCategoricalImputer(most_frequent_category_features)),
        ('feature_combiner', FeatureCombiner(combined_nominal_features)),
        ('diagnosis_mapper', DiagnosisMapper(diagnosis_features)),
        ('homogeneity_threshold', CategoricalHomogeneityThreshold(threshold=0.05, verbose=True)),
        ('category_collapse_threshold', CategoryCollapseThreshold(threshold=0.05, special_cases=merge_categories_special_cases, verbose=True))
    ]
    
    return Pipeline([
        ('column_filter', ColumnFilter(columns_to_drop)),
        ('row_filter', RowFilter(row_filters)),
        ('features', PandasFeatureUnion([
            ('numerical', Pipeline([
                ('column_selector', ColumnSelector(numerical_features)),
                ('simple_imputer', SimpleImputerDF(strategy='median')),
                ('log1p_transformer', FunctionTransformerDF(np.log1p)),
                ('standard_scaler', StandardScalerDF()),
                ('feature_combiner', FeatureCombiner(combined_numerical_features)),
                ('variance_threshold', VarianceThresholdDF(0.1))
            ])),
            ('ordinal', Pipeline([
                ('column_selector', ColumnSelector(ordinal_features)),
                ('simple_imputer', SimpleImputerDF(strategy='most_frequent')),
                ('ordinal_encoder', OrdinalEncoder(return_df=True))
            ])),
            ('nominal', Pipeline(nominal_transformers))
        ]))
    ])


preprocessor = create_pipeline()

# %%
_ = preprocessor.fit(X_train)
# Out:
# [CategoricalHomogeneityThreshold] Column: nateglinide, Entropy: 0.042513186153034996. Dropping column
# [CategoricalHomogeneityThreshold] Column: chlorpropamide, Entropy: 0.008258907529230738. Dropping column
# [CategoricalHomogeneityThreshold] Column: acetohexamide, Entropy: -0.0. Dropping column
# [CategoricalHomogeneityThreshold] Column: tolbutamide, Entropy: 0.0023252227478738605. Dropping column
# [CategoricalHomogeneityThreshold] Column: acarbose, Entropy: 0.020277208580227035. Dropping column
# [CategoricalHomogeneityThreshold] Column: miglitol, Entropy: 0.0026028569966102732. Dropping column
# [CategoricalHomogeneityThreshold] Column: troglitazone, Entropy: 0.00021325502467218777. Dropping column
# [CategoricalHomogeneityThreshold] Column: tolazamide, Entropy: 0.0036159107434984078. Dropping column
# [CategoricalHomogeneityThreshold] Column: glyburide-metformin, Entropy: 0.043473537232382196. Dropping column
# [CategoricalHomogeneityThreshold] Column: glipizide-metformin, Entropy: 0.0010873898712168487. Dropping column
# [CategoricalHomogeneityThreshold] Column: metformin-rosiglitazone, Entropy: 0.0004017336792911485. Dropping column
# [CategoricalHomogeneityThreshold] Column: metformin-pioglitazone, Entropy: -0.0. Dropping column
# [CategoryCollapseThreshold=0.05] Column: race, Value: (Not Available, 0.02729). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: race, Value: (Hispanic, 0.02188). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: race, Value: (Other, 0.01657). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: race, Value: (Asian, 0.0069). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: gender, Value: (Unknown/Invalid, 4e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: admission_type_id, Value: (7, 0.00023). Replacing value with 9.
# [CategoryCollapseThreshold=0.05] Column: admission_type_id, Value: (4, 0.00011). Replacing value with 9.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (25, 0.04654). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (2, 0.02216). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (22, 0.02028). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (5, 0.01305). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (4, 0.00794). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (7, 0.00581). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (23, 0.00359). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (28, 0.00123). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (8, 0.00104). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (15, 0.00052). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (24, 0.00038). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (17, 0.00014). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (9, 0.00013). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (16, 5e-05). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (27, 5e-05). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: discharge_disposition_id, Value: (12, 4e-05). Replacing value with 30.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (4, 0.03612). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (6, 0.02581). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (2, 0.01247). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (5, 0.00704). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (3, 0.002). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (9, 0.0013). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (8, 0.00011). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (10, 9e-05). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (22, 7e-05). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: admission_source_id, Value: (25, 4e-05). Replacing value with 27.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-General, 0.03201). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Orthopedics, 0.01601). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Orthopedics-Reconstructive, 0.01469). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Nephrology, 0.01156). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Radiologist, 0.01144). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pulmonology, 0.00928). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Psychiatry, 0.00892). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (ObstetricsandGynecology, 0.00838). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Urology, 0.00749). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Cardiovascular/Thoracic, 0.00686). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Neuro, 0.00561). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Gastroenterology, 0.00534). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Vascular, 0.00513). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Oncology, 0.00302). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (PhysicalMedicineandRehabilitation, 0.00284). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics, 0.00279). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Neurology, 0.00248). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-Endocrinology, 0.00218). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Hematology/Oncology, 0.00159). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Otolaryngology, 0.00159). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Endocrinology, 0.00147). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Thoracic, 0.00127). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Cardiovascular, 0.00116). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-CriticalCare, 0.00113). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Podiatry, 0.00089). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Gynecology, 0.00084). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Psychology, 0.00077). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Radiology, 0.00057). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Osteopath, 0.00055). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Ophthalmology, 0.00054). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgeon, 0.0005). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Hospitalist, 0.00048). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Hematology, 0.00046). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (InfectiousDiseases, 0.00043). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Plastic, 0.00041). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (SurgicalSpecialty, 0.00036). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Obsterics&Gynecology-GynecologicOnco, 0.0003). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Obstetrics, 0.00025). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Anesthesiology-Pediatric, 0.00018). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Rheumatology, 0.00016). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (OutreachServices, 0.00013). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Maxillofacial, 0.00013). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Colon&Rectal, 0.00013). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Anesthesiology, 0.00011). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-Pulmonology, 0.00011). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-Neurology, 0.00011). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Cardiology-Pediatric, 9e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (PhysicianNotFound, 9e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Endocrinology-Metabolism, 9e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pathology, 9e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-Pediatric, 7e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Dentistry, 7e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (DCPTEAM, 7e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (AllergyandImmunology, 7e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Psychiatry-Child/Adolescent, 7e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-EmergencyMedicine, 4e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Pediatrics-Hematology-Oncology, 4e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Dermatology, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (SportsMedicine, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Resident, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Psychiatry-Addictive, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Surgery-PlasticwithinHeadandNeck, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Proctology, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Neurophysiology, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Perinatology, 2e-05). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: medical_specialty, Value: (Speech, 0.0). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: max_glu_serum, Value: (Norm, 0.02434). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: max_glu_serum, Value: (>200, 0.01328). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: max_glu_serum, Value: (>300, 0.01001). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: A1Cresult, Value: (>7, 0.04118). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: metformin, Value: (Up, 0.01176). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: metformin, Value: (Down, 0.00615). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: repaglinide, Value: (Steady, 0.01137). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: repaglinide, Value: (Up, 0.001). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: repaglinide, Value: (Down, 0.00043). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glimepiride, Value: (Steady, 0.04745). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glimepiride, Value: (Up, 0.00336). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glimepiride, Value: (Down, 0.00186). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glipizide, Value: (Up, 0.00792). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glipizide, Value: (Down, 0.00542). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glyburide, Value: (Up, 0.00888). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: glyburide, Value: (Down, 0.00586). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: pioglitazone, Value: (Up, 0.00273). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: pioglitazone, Value: (Down, 0.00113). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: rosiglitazone, Value: (Up, 0.00179). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: rosiglitazone, Value: (Down, 0.00105). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Genitourinary, 0.04963). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Neoplasms, 0.03616). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Ill-defined, 0.03122). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Skin, 0.02574). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Infectious/Parasitic, 0.02477). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Mental, 0.02195). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: ((V) Health contact, 0.01292). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Nervous, 0.01231). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Blood, 0.00899). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Pregnancy, 0.00806). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Congenital, 0.00055). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t1, Value: (Other, 0.00016). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t2, Value: (Genitourinary, 0.04963). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t2, Value: (Neoplasms, 0.03616). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_1_t2, Value: (Endocrine, 0.02647). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Digestive, 0.04109). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Skin, 0.03178). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Blood, 0.02997). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Ill-defined, 0.02781). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Mental, 0.02697). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Injury/Poison, 0.0257). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Neoplasms, 0.02261). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Musculoskeletal, 0.01859). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Infectious/Parasitic, 0.01764). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: ((V) Health contact, 0.01762). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Nervous, 0.01287). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: ((E) Injury/Poison, 0.00792). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Pregnancy, 0.00491). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Other, 0.0042). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t1, Value: (Congenital, 0.00129). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t2, Value: (Digestive, 0.04109). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t2, Value: (Injury, 0.0257). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t2, Value: (Neoplasms, 0.02261). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_2_t2, Value: (Musculoskeletal, 0.01859). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Digestive, 0.03894). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: ((V) Health contact, 0.037). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Mental, 0.03078). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Ill-defined, 0.02763). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Blood, 0.02477). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Skin, 0.0213). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Injury/Poison, 0.02025). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Musculoskeletal, 0.01957). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Nervous, 0.01785). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Other, 0.01778). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Infectious/Parasitic, 0.01746). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Neoplasms, 0.01632). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: ((E) Injury/Poison, 0.01267). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Pregnancy, 0.00357). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t1, Value: (Congenital, 0.00113). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t2, Value: (Digestive, 0.03894). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t2, Value: (Injury, 0.02025). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t2, Value: (Musculoskeletal, 0.01957). Replacing value with Other.
# [CategoryCollapseThreshold=0.05] Column: diag_3_t2, Value: (Neoplasms, 0.01632). Replacing value with Other.

# %%
X_train_enc = preprocessor.transform(X_train)
X_train_one_hot_enc = pd.get_dummies(X_train_enc, drop_first=True)

# %%
X_test_enc = preprocessor.transform(X_test)
X_test_enc
# Out:
#                           days_in_hospital  num_lab_procedures  \
# 37967076     15228135           Other        Other
# 77890116     88434351           Other        Other
# ...                               ...          ...
# 132221820    37045449     Circulatory  Circulatory
# 2736744      42470721           Other        Other
# 35358396     91801431     Circulatory  Circulatory
# 276079278    58301361     Respiratory  Respiratory
# 73194312     5420682            Other        Other
#
# [14010 rows x 35 columns]

# %%
X_test_one_hot_enc = pd.get_dummies(X_test_enc, drop_first=True)
X_test_one_hot_enc
# Out:
#                           days_in_hospital  num_lab_procedures  \
# encounter_id patient_nbr
# 103798830    107100180           -1.550549           -0.190032
# 79821444     442683               0.166681            0.385846
# 293632478    93097674            -1.550549           -0.001945
# 37967076     15228135             0.508371            0.661379
# 77890116     88434351            -0.251515            0.681833
# ...                                    ...                 ...
# 132221820    37045449             1.268258           -3.637553
# 2736744      42470721             0.166681            0.460591
# 35358396     91801431             1.957415            0.834484
# 276079278    58301361            -0.790663            0.721767
# 73194312     5420682             -0.251515            0.359911
#
#                           num_procedures  num_medications  number_outpatient  \
# encounter_id patient_nbr
# 103798830    107100180         -0.984288        -0.779941          -0.352189
# 79821444     442683             1.708494         0.273885          -0.352189
# 293632478    93097674           0.057423        -2.156531          -0.352189
# 37967076     15228135           0.057423         1.334572          -0.352189
# 77890116     88434351           0.057423        -2.599693          -0.352189
# ...                                  ...              ...                ...
# 132221820    37045449          -0.984288         0.153485          -0.352189
# 2736744      42470721          -0.984288         0.494779          -0.352189
# 35358396     91801431           0.057423         1.591187          -0.352189
# 276079278    58301361          -0.984288        -0.590656          -0.352189
# 73194312     5420682           -0.984288        -2.156531          -0.352189
#
#                           number_emergency  number_inpatient  \
# encounter_id patient_nbr
# 103798830    107100180           -0.263139         -0.340827
# 79821444     442683              -0.263139         -0.340827
# 293632478    93097674            -0.263139          2.000504
# 37967076     15228135            -0.263139         -0.340827
# 77890116     88434351             2.759990          3.370095
# ...                                    ...               ...
# 132221820    37045449            -0.263139         -0.340827
# 2736744      42470721            -0.263139         -0.340827
# 35358396     91801431            -0.263139         -0.340827
# 276079278    58301361            -0.263139         -0.340827
# 73194312     5420682             -0.263139         -0.340827
#
#                           number_diagnoses  service_utilization  age  \
# encounter_id patient_nbr
# 103798830    107100180           -0.427040            -0.956154    3
# 79821444     442683               0.802368            -0.956154    1
# 293632478    93097674             0.802368             1.385177    1
# 37967076     15228135             0.439205            -0.956154    5
# 77890116     88434351            -1.586812             5.777895    3
# ...                                    ...                  ...  ...
# 132221820    37045449             0.802368            -0.956154    4
# 2736744      42470721             0.033223            -0.956154    4
# 35358396     91801431             0.802368            -0.956154    4
# 276079278    58301361            -1.586812            -0.956154    5
# 73194312     5420682             -3.347556            -0.956154    7
#
#                           race_Caucasian  race_Other  gender_Male  \
# encounter_id patient_nbr
# 103798830    107100180                 1           0            0
# 79821444     442683                    1           0            1
# 293632478    93097674                  1           0            0
# 37967076     15228135                  0           0            0
# 77890116     88434351                  1           0            1
# ...                                  ...         ...          ...
# 132221820    37045449                  1           0            1
# 2736744      42470721                  1           0            0
# 35358396     91801431                  1           0            1
# 276079278    58301361                  0           0            1
# 73194312     5420682                   0           0            0
# 2736744      42470721                      0                    0
# 35358396     91801431                      0                    0
# 276079278    58301361                      0                    0
# 73194312     5420682                       0                    1
#
#                           diag_2_t2_Genitourinary  diag_2_t2_Other  \
# encounter_id patient_nbr
# 103798830    107100180                          0                1
# 79821444     442683                             0                0
# 293632478    93097674                           0                1
# 37967076     15228135                           0                1
# 77890116     88434351                           0                1
# ...                                           ...              ...
# 132221820    37045449                           0                1
# 2736744      42470721                           0                0
# 35358396     91801431                           0                0
# 276079278    58301361                           0                0
# 73194312     5420682                            0                0
#
#                           diag_2_t2_Respiratory  diag_3_t1_Endocrine  \
# encounter_id patient_nbr
# 103798830    107100180                        0                    0
# 79821444     442683                           0                    0
# 293632478    93097674                         0                    1
# 37967076     15228135                         0                    0
# 77890116     88434351                         0                    0
# ...                                         ...                  ...
# 132221820    37045449                         0                    0
# 2736744      42470721                         0                    0
# 35358396     91801431                         0                    0
# 276079278    58301361                         1                    0
# 73194312     5420682                          0                    0
#
#                           diag_3_t1_Genitourinary  diag_3_t1_Other  \
# encounter_id patient_nbr
# 103798830    107100180                          0                1
# 79821444     442683                             0                0
# 293632478    93097674                           0                0
# 37967076     15228135                           0                1
# 77890116     88434351                           0                1
# ...                                           ...              ...
# 132221820    37045449                           0                0
# 2736744      42470721                           0                1
# 35358396     91801431                           0                0
# 276079278    58301361                           0                0
# 73194312     5420682                            0                1
#
#                           diag_3_t1_Respiratory  diag_3_t2_Diabetes  \
# encounter_id patient_nbr
# 103798830    107100180                        0                   0
# 79821444     442683                           0                   0
# 293632478    93097674                         0                   1
# 37967076     15228135                         0                   0
# 77890116     88434351                         0                   0
# ...                                         ...                 ...
# 132221820    37045449                         0                   0
# 2736744      42470721                         0                   0
# 35358396     91801431                         0                   0
# 276079278    58301361                         1                   0
# 73194312     5420682                          0                   0
#
#                           diag_3_t2_Endocrine  diag_3_t2_Genitourinary  \
# encounter_id patient_nbr
# 103798830    107100180                      0                        0
# 79821444     442683                         0                        0
# 293632478    93097674                       0                        0
# 37967076     15228135                       0                        0
# 77890116     88434351                       0                        0
# ...                                       ...                      ...
# 132221820    37045449                       0                        0
# 2736744      42470721                       0                        0
# 35358396     91801431                       0                        0
# 276079278    58301361                       0                        0
# 73194312     5420682                        0                        0
#
#                           diag_3_t2_Other  diag_3_t2_Respiratory
# encounter_id patient_nbr
# 103798830    107100180                  1                      0
# 79821444     442683                     0                      0
# 293632478    93097674                   0                      0
# 37967076     15228135                   1                      0
# 77890116     88434351                   1                      0
# ...                                   ...                    ...
# 132221820    37045449                   0                      0
# 2736744      42470721                   1                      0
# 35358396     91801431                   0                      0
# 276079278    58301361                   0                      1
# 73194312     5420682                    1                      0
#
# [14010 rows x 82 columns]

# %% [markdown]
# ## 6. Exporting Preprocessed Data

# %%
X_train_enc.to_pickle(ld.find_preprocessed_path('X_train.pkl'))
X_test_enc.to_pickle(ld.find_preprocessed_path('X_test.pkl'))
X_train_one_hot_enc.to_pickle(ld.find_preprocessed_path('X_train_one_hot.pkl'))
X_test_one_hot_enc.to_pickle(ld.find_preprocessed_path('X_test_one_hot.pkl'))
